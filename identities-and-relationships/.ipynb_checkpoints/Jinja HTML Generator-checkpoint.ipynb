# %% [markdown]
# This file generates the html tags for the query terms

# %%
import os

# %% [markdown]
# Get the file names from the htmlPages directory

# %%
files = os.listdir('htmlPages')
#print(files)
files.remove(".DS_Store")
len(files)
# Out:
# 130

# %%
files.sort()

# %%
import json

# %%
# Load from the identity file

with open('identitiesQueryList.json') as inFile:
    identitiesList = json.load(inFile)
#print(identitiesList)

# %%
identities = []
for f in files:    
    queryName = f[0:f.find("_")]
    #print(queryName)
    if queryName in identitiesList:
        filePath = "htmlPages/"+f
        identities.append({"filePath":filePath, "queryName":queryName})
        #print(filePath)
#print(identities)

# %%
# Load from the relationship file

with open('relationshipsQueryList.json') as inFile:
    relationshipsList = json.load(inFile)
#print(relationshipsList)

# %%
relationships = []
for f in files:    
    queryName = f[0:f.find("_")]
    #print(queryName)
    if queryName in relationshipsList:
        filePath = "htmlPages/"+f
        relationships.append({"filePath":filePath, "queryName":queryName})
        #print(filePath)
#print(relationships)

# %%
from jinja2 import Template

# %%
#Create the HTML template for identities

htmlTemplate = """
<DOCTYPE html>
<html>
    <head><title>Queries</title></head>
    <body>
        <h1>Identities</h1>
        <ul>
        {% for identity in identities %}
            <li><a id="{{ identity['queryName'] }}" data-src="{{identity['filePath']}}">{{identity['queryName']}}</a></li> 
        {% endfor %}
        </ul>
    </body>
</html>
"""

tempObj = Template(htmlTemplate)

# %%
#Render the template by passing as an argument the list of objects.

result = tempObj.render(identities=identities)
print(result)
# Out:
# <DOCTYPE html>
# <html>
#     <head><title>Queries</title></head>
#     <body>
#         <h1>Identities</h1>
#         <ul>
#
#             <li><a id="(f)ae (f)aer" data-src="htmlPages/(f)ae (f)aer_P5.html">(f)ae (f)aer</a></li>
#
#             <li><a id="Ace" data-src="htmlPages/Ace_P7.html">Ace</a></li>
#
#             <li><a id="Agender" data-src="htmlPages/Agender_P7.html">Agender</a></li>
#
#             <li><a id="Alternate pronouns" data-src="htmlPages/Alternate pronouns_P7.html">Alternate pronouns</a></li>
#
#             <li><a id="Aro Ace" data-src="htmlPages/Aro Ace_P7.html">Aro Ace</a></li>
#
#             <li><a id="Aromantic" data-src="htmlPages/Aromantic_P7.html">Aromantic</a></li>
#
#             <li><a id="Asexual" data-src="htmlPages/Asexual_P7.html">Asexual</a></li>
#
#             <li><a id="Asexuality" data-src="htmlPages/Asexuality_P4.html">Asexuality</a></li>
#
#             <li><a id="Bi" data-src="htmlPages/Bi_P7.html">Bi</a></li>
#
#             <li><a id="Bisexual" data-src="htmlPages/Bisexual_P7.html">Bisexual</a></li>
#
#             <li><a id="Bisexuality versus pansexuality" data-src="htmlPages/Bisexuality versus pansexuality_P4.html">Bisexuality versus pansexuality</a></li>
#
#             <li><a id="Cisgender" data-src="htmlPages/Cisgender_P5.html">Cisgender</a></li>
#
#             <li><a id="Coming out experiences" data-src="htmlPages/Coming out experiences_P7.html">Coming out experiences</a></li>
#
#             <li><a id="Coming out" data-src="htmlPages/Coming out_P7.html">Coming out</a></li>
#
#             <li><a id="Demisexual" data-src="htmlPages/Demisexual_P7.html">Demisexual</a></li>
#
#             <li><a id="Diversity" data-src="htmlPages/Diversity_P5.html">Diversity</a></li>
#
#             <li><a id="Gay" data-src="htmlPages/Gay_P7.html">Gay</a></li>
#
#             <li><a id="Gender binary" data-src="htmlPages/Gender binary_P4.html">Gender binary</a></li>
#
#             <li><a id="Gender dysphoria" data-src="htmlPages/Gender dysphoria_P7.html">Gender dysphoria</a></li>
#
#             <li><a id="Gender expression" data-src="htmlPages/Gender expression_P5.html">Gender expression</a></li>
#
#             <li><a id="Gender expression" data-src="htmlPages/Gender expression_P7.html">Gender expression</a></li>
#
#             <li><a id="Gender identities" data-src="htmlPages/Gender identities_P7.html">Gender identities</a></li>
#
#             <li><a id="Gender identity" data-src="htmlPages/Gender identity_P5.html">Gender identity</a></li>
#
#             <li><a id="Gender neutral gender inclusive pronouns" data-src="htmlPages/Gender neutral gender inclusive pronouns_P5.html">Gender neutral gender inclusive pronouns</a></li>
#
#             <li><a id="Gender neutral pronouns" data-src="htmlPages/Gender neutral pronouns_P7.html">Gender neutral pronouns</a></li>
#
#             <li><a id="Gender non-conforming" data-src="htmlPages/Gender non-conforming_P5.html">Gender non-conforming</a></li>
#
#             <li><a id="Gender non-conforming" data-src="htmlPages/Gender non-conforming_P7.html">Gender non-conforming</a></li>
#
#             <li><a id="Gender pronouns" data-src="htmlPages/Gender pronouns_P7.html">Gender pronouns</a></li>
#
#             <li><a id="Gender questioning" data-src="htmlPages/Gender questioning_P7.html">Gender questioning</a></li>
#
#             <li><a id="Gender reassignment surgeries" data-src="htmlPages/Gender reassignment surgeries_P7.html">Gender reassignment surgeries</a></li>
#
#             <li><a id="Gender reassignment" data-src="htmlPages/Gender reassignment_P7.html">Gender reassignment</a></li>
#
#             <li><a id="Gender transitions" data-src="htmlPages/Gender transitions_P7.html">Gender transitions</a></li>
#
#             <li><a id="Gender-affirming practices" data-src="htmlPages/Gender-affirming practices_P4.html">Gender-affirming practices</a></li>
#
#             <li><a id="Gender-expansive" data-src="htmlPages/Gender-expansive_P7.html">Gender-expansive</a></li>
#
#             <li><a id="Gender-reaffirming resources free" data-src="htmlPages/Gender-reaffirming resources free_P4.html">Gender-reaffirming resources free</a></li>
#
#             <li><a id="Genderfluid" data-src="htmlPages/Genderfluid_P5.html">Genderfluid</a></li>
#
#             <li><a id="Genderfluid" data-src="htmlPages/Genderfluid_P7.html">Genderfluid</a></li>
#
#             <li><a id="Genderqueer" data-src="htmlPages/Genderqueer_P7.html">Genderqueer</a></li>
#
#             <li><a id="How to be a LGBTQ+ ally" data-src="htmlPages/How to be a LGBTQ+ ally_P7.html">How to be a LGBTQ+ ally</a></li>
#
#             <li><a id="How to come out" data-src="htmlPages/How to come out_P4.html">How to come out</a></li>
#
#             <li><a id="How to create space for LGBTQ+ community" data-src="htmlPages/How to create space for LGBTQ+ community_P4.html">How to create space for LGBTQ+ community</a></li>
#
#             <li><a id="How to have LGBTQ terminology that is less binary" data-src="htmlPages/How to have LGBTQ terminology that is less binary_P4.html">How to have LGBTQ terminology that is less binary</a></li>
#
#             <li><a id="How to introduce new pronouns to your friends" data-src="htmlPages/How to introduce new pronouns to your friends_P4.html">How to introduce new pronouns to your friends</a></li>
#
#             <li><a id="Inclusion" data-src="htmlPages/Inclusion_P5.html">Inclusion</a></li>
#
#             <li><a id="Intersectionality" data-src="htmlPages/Intersectionality_P4.html">Intersectionality</a></li>
#
#             <li><a id="Intersex" data-src="htmlPages/Intersex_P7.html">Intersex</a></li>
#
#             <li><a id="Is being queer the same as being gay" data-src="htmlPages/Is being queer the same as being gay_P4.html">Is being queer the same as being gay</a></li>
#
#             <li><a id="LGBTQ+ Resources" data-src="htmlPages/LGBTQ+ Resources_P4.html">LGBTQ+ Resources</a></li>
#
#             <li><a id="LGBTQ+ discrimination" data-src="htmlPages/LGBTQ+ discrimination_P7.html">LGBTQ+ discrimination</a></li>
#
#             <li><a id="LGBTQ+" data-src="htmlPages/LGBTQ+_P5.html">LGBTQ+</a></li>
#
#             <li><a id="LGBTQ+" data-src="htmlPages/LGBTQ+_P7.html">LGBTQ+</a></li>
#
#             <li><a id="Lesbian" data-src="htmlPages/Lesbian_P7.html">Lesbian</a></li>
#
#             <li><a id="Neopronouns" data-src="htmlPages/Neopronouns_P7.html">Neopronouns</a></li>
#
#             <li><a id="Non-binary Gender Queer" data-src="htmlPages/Non-binary Gender Queer_P5.html">Non-binary Gender Queer</a></li>
#
#             <li><a id="Non-binary practices in different cultures" data-src="htmlPages/Non-binary practices in different cultures_P4.html">Non-binary practices in different cultures</a></li>
#
#             <li><a id="Non-binary versus agender" data-src="htmlPages/Non-binary versus agender_P4.html">Non-binary versus agender</a></li>
#
#             <li><a id="Non-heterosexual" data-src="htmlPages/Non-heterosexual_P5.html">Non-heterosexual</a></li>
#
#             <li><a id="Nonbinary" data-src="htmlPages/Nonbinary_P7.html">Nonbinary</a></li>
#
#             <li><a id="Omnigender" data-src="htmlPages/Omnigender_P7.html">Omnigender</a></li>
#
#             <li><a id="Omnisexual" data-src="htmlPages/Omnisexual_P7.html">Omnisexual</a></li>
#
#             <li><a id="Pronouns definition" data-src="htmlPages/Pronouns definition_P5.html">Pronouns definition</a></li>
#
#             <li><a id="Pronouns" data-src="htmlPages/Pronouns_P4.html">Pronouns</a></li>
#
#             <li><a id="Pronouns" data-src="htmlPages/Pronouns_P5.html">Pronouns</a></li>
#
#             <li><a id="Queer identities definition" data-src="htmlPages/Queer identities definition_P5.html">Queer identities definition</a></li>
#
#             <li><a id="Queer identities" data-src="htmlPages/Queer identities_P5.html">Queer identities</a></li>
#
#             <li><a id="Queer" data-src="htmlPages/Queer_P7.html">Queer</a></li>
#
#             <li><a id="Sex assigned at birth" data-src="htmlPages/Sex assigned at birth_P5.html">Sex assigned at birth</a></li>
#
#             <li><a id="Sexual Minority" data-src="htmlPages/Sexual Minority_P5.html">Sexual Minority</a></li>
#
#             <li><a id="Sexual orientation" data-src="htmlPages/Sexual orientation_P5.html">Sexual orientation</a></li>
#
#             <li><a id="Trans" data-src="htmlPages/Trans_P7.html">Trans</a></li>
#
#             <li><a id="Transgender" data-src="htmlPages/Transgender_P4.html">Transgender</a></li>
#
#             <li><a id="Transgender" data-src="htmlPages/Transgender_P5.html">Transgender</a></li>
#
#             <li><a id="Transgender" data-src="htmlPages/Transgender_P7.html">Transgender</a></li>
#
#             <li><a id="Two-spirit" data-src="htmlPages/Two-spirit_P7.html">Two-spirit</a></li>
#
#             <li><a id="What are pronouns" data-src="htmlPages/What are pronouns_P4.html">What are pronouns</a></li>
#
#             <li><a id="What does it mean to identify as queer" data-src="htmlPages/What does it mean to identify as queer_P4.html">What does it mean to identify as queer</a></li>
#
#             <li><a id="Why it is important for everyone to include their pronouns on social media etc." data-src="htmlPages/Why it is important for everyone to include their pronouns on social media etc._P4.html">Why it is important for everyone to include their pronouns on social media etc.</a></li>
#
#             <li><a id="e em" data-src="htmlPages/e em_P5.html">e em</a></li>
#
#             <li><a id="gender identities" data-src="htmlPages/gender identities_P1.html">gender identities</a></li>
#
#             <li><a id="he him" data-src="htmlPages/he him_P5.html">he him</a></li>
#
#             <li><a id="per per" data-src="htmlPages/per per_P5.html">per per</a></li>
#
#             <li><a id="queer identities and pronouns " data-src="htmlPages/queer identities and pronouns _P1.html">queer identities and pronouns </a></li>
#
#             <li><a id="queer identities" data-src="htmlPages/queer identities_P1.html">queer identities</a></li>
#
#             <li><a id="she her" data-src="htmlPages/she her_P5.html">she her</a></li>
#
#             <li><a id="they them" data-src="htmlPages/they them_P5.html">they them</a></li>
#
#             <li><a id="ve ver" data-src="htmlPages/ve ver_P5.html">ve ver</a></li>
#
#             <li><a id="xe xem" data-src="htmlPages/xe xem_P5.html">xe xem</a></li>
#
#             <li><a id="ze hir" data-src="htmlPages/ze hir_P5.html">ze hir</a></li>
#
#         </ul>
#     </body>
# </html>

# %%
with open('identityQueryTags.html', 'w') as outFile:
    outFile.write(result)

# %%
#Create the HTML template for relationships

htmlTemplate = """
<DOCTYPE html>
<html>
    <head><title>Queries</title></head>
    <body>
        <h1>Relationships</h1>
        <ul>
        {% for relationship in relationships %}
            <li><a id="{{ relationship['queryName'] }}" data-src="{{relationship['filePath']}}">{{relationship['queryName']}}</a></li> 
        {% endfor %}
        </ul>
    </body>
</html>
"""

tempObj = Template(htmlTemplate)

# %%
#Render the template by passing as an argument the list of objects.

result = tempObj.render(relationships=relationships)
print(result)
# Out:
# <DOCTYPE html>
# <html>
#     <head><title>Queries</title></head>
#     <body>
#         <h1>Relationships</h1>
#         <ul>
#
#             <li><a id="Abusive relationship cycle" data-src="htmlPages/Abusive relationship cycle_P3.html">Abusive relationship cycle</a></li>
#
#             <li><a id="Abusive relationship help MA " data-src="htmlPages/Abusive relationship help MA _P3.html">Abusive relationship help MA </a></li>
#
#             <li><a id="Abusive relationship help" data-src="htmlPages/Abusive relationship help_P3.html">Abusive relationship help</a></li>
#
#             <li><a id="Abusive relationship signs" data-src="htmlPages/Abusive relationship signs_P3.html">Abusive relationship signs</a></li>
#
#             <li><a id="Abusive relationship types " data-src="htmlPages/Abusive relationship types _P3.html">Abusive relationship types </a></li>
#
#             <li><a id="Abusive relationship" data-src="htmlPages/Abusive relationship_P3.html">Abusive relationship</a></li>
#
#             <li><a id="Attachment styles and cycles of abuse" data-src="htmlPages/Attachment styles and cycles of abuse_P4.html">Attachment styles and cycles of abuse</a></li>
#
#             <li><a id="Communities for victims of partner-based violence" data-src="htmlPages/Communities for victims of partner-based violence_P4.html">Communities for victims of partner-based violence</a></li>
#
#             <li><a id="Different kinds of domestic abuse" data-src="htmlPages/Different kinds of domestic abuse_P6.html">Different kinds of domestic abuse</a></li>
#
#             <li><a id="Domestic violence hotlines and resources" data-src="htmlPages/Domestic violence hotlines and resources_P6.html">Domestic violence hotlines and resources</a></li>
#
#             <li><a id="Domestic violence" data-src="htmlPages/Domestic violence_P6.html">Domestic violence</a></li>
#
#             <li><a id="Emotional vs physical abuse" data-src="htmlPages/Emotional vs physical abuse_P6.html">Emotional vs physical abuse</a></li>
#
#             <li><a id="Gaslighting" data-src="htmlPages/Gaslighting_P3.html">Gaslighting</a></li>
#
#             <li><a id="Healthy vs unhealthy love" data-src="htmlPages/Healthy vs unhealthy love_P4.html">Healthy vs unhealthy love</a></li>
#
#             <li><a id="Hotlines for those in abusive relationships" data-src="htmlPages/Hotlines for those in abusive relationships_P4.html">Hotlines for those in abusive relationships</a></li>
#
#             <li><a id="How become financially independent in a relationship" data-src="htmlPages/How become financially independent in a relationship_P4.html">How become financially independent in a relationship</a></li>
#
#             <li><a id="How many women die from domestic violence" data-src="htmlPages/How many women die from domestic violence_P6.html">How many women die from domestic violence</a></li>
#
#             <li><a id="How many women suffer from violence in relationships" data-src="htmlPages/How many women suffer from violence in relationships_P6.html">How many women suffer from violence in relationships</a></li>
#
#             <li><a id="How to get out of a toxic relationship" data-src="htmlPages/How to get out of a toxic relationship_P4.html">How to get out of a toxic relationship</a></li>
#
#             <li><a id="How to help a friend in an abusive relationship" data-src="htmlPages/How to help a friend in an abusive relationship_P6.html">How to help a friend in an abusive relationship</a></li>
#
#             <li><a id="How to learn to receive healthy love" data-src="htmlPages/How to learn to receive healthy love_P4.html">How to learn to receive healthy love</a></li>
#
#             <li><a id="How to leave an abusive relationship" data-src="htmlPages/How to leave an abusive relationship_P6.html">How to leave an abusive relationship</a></li>
#
#             <li><a id="How to recognize an abusive partner" data-src="htmlPages/How to recognize an abusive partner_P6.html">How to recognize an abusive partner</a></li>
#
#             <li><a id="How to recognize emotional abuse in relationships" data-src="htmlPages/How to recognize emotional abuse in relationships_P4.html">How to recognize emotional abuse in relationships</a></li>
#
#             <li><a id="How to recover from an abusive relationship" data-src="htmlPages/How to recover from an abusive relationship_P6.html">How to recover from an abusive relationship</a></li>
#
#             <li><a id="Learning about attachment styles" data-src="htmlPages/Learning about attachment styles_P4.html">Learning about attachment styles</a></li>
#
#             <li><a id="Partner abuse" data-src="htmlPages/Partner abuse_P6.html">Partner abuse</a></li>
#
#             <li><a id="Resources for reporting partner abuse" data-src="htmlPages/Resources for reporting partner abuse_P4.html">Resources for reporting partner abuse</a></li>
#
#             <li><a id="Safety plan domestic violence" data-src="htmlPages/Safety plan domestic violence_P6.html">Safety plan domestic violence</a></li>
#
#             <li><a id="Toxic relationship patterns" data-src="htmlPages/Toxic relationship patterns_P3.html">Toxic relationship patterns</a></li>
#
#             <li><a id="Toxic relationship test " data-src="htmlPages/Toxic relationship test _P3.html">Toxic relationship test </a></li>
#
#             <li><a id="Toxic relationship" data-src="htmlPages/Toxic relationship_P3.html">Toxic relationship</a></li>
#
#             <li><a id="What are characteristics of a toxic relationship" data-src="htmlPages/What are characteristics of a toxic relationship_P4.html">What are characteristics of a toxic relationship</a></li>
#
#             <li><a id="What are types of partner-based violence" data-src="htmlPages/What are types of partner-based violence_P4.html">What are types of partner-based violence</a></li>
#
#             <li><a id="What is financial abuse in relationships" data-src="htmlPages/What is financial abuse in relationships_P4.html">What is financial abuse in relationships</a></li>
#
#             <li><a id="What is trauma bonding" data-src="htmlPages/What is trauma bonding_P6.html">What is trauma bonding</a></li>
#
#             <li><a id="Why do people stay in toxic relationships" data-src="htmlPages/Why do people stay in toxic relationships_P6.html">Why do people stay in toxic relationships</a></li>
#
#             <li><a id="Why is it hard to leave an abusive partner" data-src="htmlPages/Why is it hard to leave an abusive partner_P6.html">Why is it hard to leave an abusive partner</a></li>
#
#             <li><a id="emotional abuse checklist" data-src="htmlPages/emotional abuse checklist_P2.html">emotional abuse checklist</a></li>
#
#             <li><a id="how to tell if you are in a toxic relationship" data-src="htmlPages/how to tell if you are in a toxic relationship_P2.html">how to tell if you are in a toxic relationship</a></li>
#
#             <li><a id="how to tell if you are in an emotionally abusive relationship" data-src="htmlPages/how to tell if you are in an emotionally abusive relationship_P2.html">how to tell if you are in an emotionally abusive relationship</a></li>
#
#         </ul>
#     </body>
# </html>

# %%
with open('relationshipQueryTags.html', 'w') as outFile:
    outFile.write(result)
